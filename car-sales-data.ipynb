# %% [markdown]
# # Car Sales Data
#
# # Introduction
#
# The "Car Sales Data" dataset is a comprehensive collection of information on car sales from a car dealership over the course of a year. This dataset consists of 2.5 million rows and nine columns of data for each car sale. The dataset provides detailed information such as the date of the sale, the name of the salesperson, the customer name, the make and model of the car, the year of the car, the sale price of the car in USD, the commission rate paid to the salesperson on the sale, and the amount of commission earned by the salesperson on the sale.
#
# The dataset is a useful resource for analyzing car sales trends over time, evaluating the performance of individual salespeople in the dealership, and predicting sales performance. It can also be used to explore the impact of different factors on car sales, such as car make, model, year, and salesperson performance. This dataset is an excellent resource for anyone interested in the car sales industry or conducting data analysis on sales data.

# %% [markdown]
# ## Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Exploration

# %%
# Read in the dataset
df = pd.read_csv('/kaggle/input/car-sales-data/car_sales_data.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Salesperson', 'Customer Name', 'Car Make', 'Car Model',
#        'Car Year', 'Sale Price', 'Commission Rate', 'Commission Earned'],
#       dtype='object')

# %% [markdown]
# **Columns Explanation:**
#
# * Date: The date of the car sale
# * Salesperson: The name of the salesperson who made the sale
# * Customer Name: The name of the customer who purchased the car
# * Car Make: The make of the car that was purchased
# * Car Model: The model of the car that was purchased
# * Car Year: The year of the car that was purchased
# * Sale Price: The sale price of the car in USD
# * Commission Rate: The commission rate paid to the salesperson on the sale
# * Commission Earned: The amount of commission earned by the salesperson on the sale

# %%
df.head()
# Out:
#          Date      Salesperson   Customer Name Car Make  Car Model  Car Year  \
# 0  2022-08-01  Monica Moore MD     Mary Butler   Nissan     Altima      2018
# 1  2023-03-15     Roberto Rose  Richard Pierce   Nissan      F-150      2016
# 2  2023-04-29     Ashley Ramos    Sandra Moore     Ford      Civic      2016
# 3  2022-09-04   Patrick Harris    Johnny Scott     Ford     Altima      2013
# 4  2022-06-16       Eric Lopez   Vanessa Jones    Honda  Silverado      2022
#
#    Sale Price  Commission Rate  Commission Earned
# 0       15983         0.070495            1126.73
# 1       38474         0.134439            5172.40
# 2       33340         0.114536            3818.63
# 3       41937         0.092191            3866.20
# 4       20256         0.113490            2298.85

# %%
df.tail()
# Out:
#                Date     Salesperson    Customer Name   Car Make  Car Model  \
# 2499995  2022-05-26  Isabella Moore      Shirley Lee  Chevrolet  Silverado
# 2499996  2022-10-03   Kimberly Snow     Tara Rodgers       Ford      F-150
# 2499997  2022-06-07   Jessica Young   Jennifer Moore  Chevrolet      Civic
# 2499998  2023-02-15   Donald Barber      Ashley Diaz      Honda  Silverado
# 2499999  2023-03-24    Kayla Fowler  Nathan Thompson      Honda      Civic
#
#          Car Year  Sale Price  Commission Rate  Commission Earned
# 2499995      2021       49823         0.062977            3137.70
# 2499996      2022       18803         0.068339            1284.97
# 2499997      2010       30863         0.088915            2744.19
# 2499998      2014       26125         0.088260            2305.80
# 2499999      2010       20762         0.137105            2846.57

# %% [markdown]
# Some initial exploratory data analysis (EDA) questions that could be asked are:
#
# * What is the size of the dataset?
# * What are the different variables present in the dataset?
# * Are there any missing values in the dataset?
# * What is the range of values for each variable?
# * Are there any outliers or unusual values in the dataset?
# * What is the distribution of the variables?
# * Are there any correlations between variables?

# %%
# Check the size of the dataset
print('Dataset size:', df.shape)
# Out:
# Dataset size: (2500000, 9)

# %%
# Check for missing values
print('Missing values:\n', df.isnull().sum())
# Out:
# Missing values:
#  Date                 0
# Salesperson          0
# Customer Name        0
# Car Make             0
# Car Model            0
# Car Year             0
# Sale Price           0
# Commission Rate      0
# Commission Earned    0
# dtype: int64

# %% [markdown]
# No missing values.

# %% [markdown]
# # EDA

# %%
display(df.describe())     # include='all',包含非數值columes；exclude,不包含何種data types
# Out:
#            Car Year    Sale Price  Commission Rate  Commission Earned
# count  2.500000e+06  2.500000e+06     2.500000e+06       2.500000e+06
# mean   2.015996e+03  3.001218e+04     9.998766e-02       3.001005e+03
# std    3.739132e+00  1.154514e+04     2.887202e-02       1.481467e+03
# min    2.010000e+03  1.000000e+04     5.000014e-02       5.013400e+02
# 25%    2.013000e+03  2.001900e+04     7.496450e-02       1.821710e+03
# 50%    2.016000e+03  3.000600e+04     1.000058e-01       2.741910e+03
# 75%    2.019000e+03  4.002200e+04     1.250065e-01       3.978142e+03
# max    2.022000e+03  5.000000e+04     1.500000e-01       7.494530e+03

# %%
# Check the range of values for each variable
print('Variable ranges:\n', df.describe())
# Out:
# Variable ranges:
#             Car Year    Sale Price  Commission Rate  Commission Earned
# count  2.500000e+06  2.500000e+06     2.500000e+06       2.500000e+06
# mean   2.015996e+03  3.001218e+04     9.998766e-02       3.001005e+03
# std    3.739132e+00  1.154514e+04     2.887202e-02       1.481467e+03
# min    2.010000e+03  1.000000e+04     5.000014e-02       5.013400e+02
# 25%    2.013000e+03  2.001900e+04     7.496450e-02       1.821710e+03
# 50%    2.016000e+03  3.000600e+04     1.000058e-01       2.741910e+03
# 75%    2.019000e+03  4.002200e+04     1.250065e-01       3.978142e+03
# max    2.022000e+03  5.000000e+04     1.500000e-01       7.494530e+03

# %% [markdown]
# * The car sales data ranges from the year 2010 to 2022, with the mean car year being 2016.
# * The average sale price for a car is around \\$30,012, with a standard deviation of \\$11,545, indicating that there is a wide range of sale prices in the dataset.
# * The commission rate ranges from 0.05 to 0.15, with an average of 0.099, indicating that the dealership pays out an average commission of 9.9% to their salespeople.
# * The average commission earned by a salesperson on a car sale is around \\$3,001, with a standard deviation of $1,481.

# %%
unique_car_makes = df['Car Make'].unique()
unique_car_models = df['Car Model'].unique()

print("Unique Car Makes: \n", unique_car_makes)
print("Unique Car Models: \n", unique_car_models)
# Out:
# Unique Car Makes:
#  ['Nissan' 'Ford' 'Honda' 'Toyota' 'Chevrolet']
# Unique Car Models:
#  ['Altima' 'F-150' 'Civic' 'Silverado' 'Corolla']

# %%
car_make_counts = df['Car Make'].value_counts()
print(car_make_counts)
# Out:
# Honda        500687
# Chevrolet    500455
# Toyota       500147
# Ford         499781
# Nissan       498930
# Name: Car Make, dtype: int64

# %%
car_model_counts = df['Car Model'].value_counts()
print(car_model_counts)
# Out:
# Silverado    500842
# Civic        500498
# Corolla      500162
# F-150        499679
# Altima       498819
# Name: Car Model, dtype: int64

# %%
Y = df['Car Year'].value_counts().sort_index()
print(Y)
# Out:
# 2010    192462
# 2011    191800
# 2012    192454
# 2013    192970
# 2014    192491
# 2015    192595
# 2016    192267
# 2017    192663
# 2018    192549
# 2019    192225
# 2020    192657
# 2021    191636
# 2022    191231
# Name: Car Year, dtype: int64

# %%
cm = df['Car Make'] == 'Honda'
print(df[cm])
# Out:
#                Date        Salesperson     Customer Name Car Make  Car Model  \
# 4        2022-06-16         Eric Lopez     Vanessa Jones    Honda  Silverado
# 6        2022-06-12       Ashley Brown      Tyler Lawson    Honda      F-150
# 10       2023-03-12      Harold Nelson      Isaac Patton    Honda  Silverado
# 15       2022-12-21    James Velasquez  Natalie Thompson    Honda    Corolla
# 25       2023-02-15       Faith Pierce        Jimmy Dunn    Honda  Silverado
# ...             ...                ...               ...      ...        ...
# 2499976  2022-09-21  Mr. Calvin Hardin   Wesley Thompson    Honda      F-150
# 2499979  2023-04-12         Shawn Park     Anna Callahan    Honda     Altima
# 2499980  2023-03-21       Jesse Thomas       Holly Evans    Honda     Altima
# 2499998  2023-02-15      Donald Barber       Ashley Diaz    Honda  Silverado
# 2499999  2023-03-24       Kayla Fowler   Nathan Thompson    Honda      Civic
#
#          Car Year  Sale Price  Commission Rate  Commission Earned
# 4            2022       20256         0.113490            2298.85
# 6            2013       41397         0.142780            5910.67
# 10           2021       41259         0.092541            3818.16
# 15           2016       36607         0.055251            2022.57
# 25           2016       35279         0.063400            2236.68
# ...           ...         ...              ...                ...
# 2499976      2013       30189         0.148767            4491.14
# 2499979      2021       31401         0.077809            2443.27
# 2499980      2015       40685         0.077628            3158.31
# 2499998      2014       26125         0.088260            2305.80
# 2499999      2010       20762         0.137105            2846.57
#
# [500687 rows x 9 columns]

# %%
car_model_perc = df['Car Model'].value_counts(normalize=True) * 100
print(car_model_perc)

car_make_perc = df['Car Make'].value_counts(normalize=True) * 100
print(car_make_perc)
# Out:
# Silverado    20.03368
# Civic        20.01992
# Corolla      20.00648
# F-150        19.98716
# Altima       19.95276
# Name: Car Model, dtype: float64
# Honda        20.02748
# Chevrolet    20.01820
# Toyota       20.00588
# Ford         19.99124
# Nissan       19.95720
# Name: Car Make, dtype: float64

# %%
import matplotlib.pyplot as plt

# Get value counts for car makes
car_make_counts = df['Car Make'].value_counts()

# Create a pie chart
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(car_make_counts, labels=car_make_counts.index, autopct='%1.9f%%', startangle=90)
ax.axis('equal')
ax.set_title('Distribution of Car Makes')

plt.show()

# %% [markdown]
# **The top 5 Car Models are Silverado, Civic, Corolla, F-150, and Altima with a percentage distribution of 20.03%, 20.02%, 20.01%, 19.99%, and 19.95% respectively.**

# %%
import matplotlib.pyplot as plt

# Get value counts for car makes
car_make_counts = df['Car Model'].value_counts()

# Create a pie chart
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(car_make_counts, labels=car_make_counts.index, autopct='%1.9f%%', startangle=90)
ax.axis('equal')
ax.set_title('Distribution of Car Models')

plt.show()

# %% [markdown]
# **The top 5 Car Makes are Honda, Chevrolet, Toyota, Ford, and Nissan with a percentage distribution of 20.03%, 20.02%, 20.01%, 19.99%, and 19.96% respectively.**

# %% [markdown]
# **Top Sales persons**

# %%
top_salespersons = df['Salesperson'].value_counts().head(5)
print(top_salespersons)
# Out:
# Michael Smith      1229
# Michael Johnson     976
# David Smith         821
# James Smith         796
# Jennifer Smith      753
# Name: Salesperson, dtype: int64

# %% [markdown]
# **Most sold car model**

# %%
most_sold_car_make = df['Car Make'].value_counts().idxmax()
print("The most sold car make is:", most_sold_car_make)
# Out:
# The most sold car make is: Honda

# %%
most_sold_model = df['Car Model'].value_counts().index[0]
print("The most sold car model is:", most_sold_model)
# Out:
# The most sold car model is: Silverado

# %% [markdown]
# The most sold car is **Honda Silvaredo**

# %% [markdown]
# **Yearly Sales**

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year
#df.drop(columns='year',axis=1,inplace=True)
print(df)
# Out:
#                Date      Salesperson    Customer Name   Car Make  Car Model  \
# 0        2022-08-01  Monica Moore MD      Mary Butler     Nissan     Altima
# 1        2023-03-15     Roberto Rose   Richard Pierce     Nissan      F-150
# 2        2023-04-29     Ashley Ramos     Sandra Moore       Ford      Civic
# 3        2022-09-04   Patrick Harris     Johnny Scott       Ford     Altima
# 4        2022-06-16       Eric Lopez    Vanessa Jones      Honda  Silverado
# ...             ...              ...              ...        ...        ...
# 2499995  2022-05-26   Isabella Moore      Shirley Lee  Chevrolet  Silverado
# 2499996  2022-10-03    Kimberly Snow     Tara Rodgers       Ford      F-150
# 2499997  2022-06-07    Jessica Young   Jennifer Moore  Chevrolet      Civic
# 2499998  2023-02-15    Donald Barber      Ashley Diaz      Honda  Silverado
# 2499999  2023-03-24     Kayla Fowler  Nathan Thompson      Honda      Civic
#
#          Car Year  Sale Price  Commission Rate  Commission Earned  Year
# 0            2018       15983         0.070495            1126.73  2022
# 1            2016       38474         0.134439            5172.40  2023
# 2            2016       33340         0.114536            3818.63  2023
# 3            2013       41937         0.092191            3866.20  2022
# 4            2022       20256         0.113490            2298.85  2022
# ...           ...         ...              ...                ...   ...
# 2499995      2021       49823         0.062977            3137.70  2022
# 2499996      2022       18803         0.068339            1284.97  2022
# 2499997      2010       30863         0.088915            2744.19  2022
# 2499998      2014       26125         0.088260            2305.80  2023
# 2499999      2010       20762         0.137105            2846.57  2023
#
# [2500000 rows x 10 columns]

# %%
Commission = df.groupby('Salesperson')['Commission Earned'].sum().reset_index()
Commission = Commission.sort_values(by='Commission Earned', ascending=False)
print(Commission.head())

Commission_y = df.groupby(['Year', 'Salesperson'])['Commission Earned'].sum().reset_index()
Commission_y = Commission_y.sort_values(by='Commission Earned', ascending=False)
print(Commission_y.head())     # 賺取的傭金
# Out:
#             Salesperson  Commission Earned
# 343406    Michael Smith         3658467.56
# 342657  Michael Johnson         2883629.29
# 123811      David Smith         2456566.33
# 213701      James Smith         2448405.59
# 425509     Robert Smith         2275950.52
#         Year      Salesperson  Commission Earned
# 286544  2022    Michael Smith         2477421.15
# 285894  2022  Michael Johnson         1977775.09
# 176831  2022      James Smith         1657237.47
# 104448  2022      David Smith         1653587.21
# 189028  2022   Jennifer Smith         1525108.19

# %%
yearly_sales = df.groupby('Car Year')['Sale Price'].sum().reset_index()
yearly_sales = yearly_sales.sort_values(by='Sale Price', ascending=False)
print(yearly_sales)
# Out:
#     Car Year  Sale Price
# 5       2015  5787448830
# 7       2017  5785627889
# 3       2013  5785345440
# 10      2020  5782422975
# 0       2010  5781746875
# 4       2014  5779464242
# 6       2016  5777008549
# 8       2018  5776261553
# 2       2012  5776172347
# 9       2019  5768079806
# 1       2011  5751909061
# 11      2021  5744104226
# 12      2022  5734855062

# %%
import matplotlib.pyplot as plt

# Group the data by year and calculate the total sales for each year
yearly_sales = df.groupby('Car Year')['Sale Price'].sum()

# Calculate the percentage of sales for each year
yearly_sales_perc = yearly_sales / yearly_sales.sum() * 100
print(yearly_sales)

# Create a line chart to visualize the yearly sales percentage
plt.plot(yearly_sales_perc.index, yearly_sales_perc.values)
plt.xlabel('Year')
plt.ylabel('Percentage of Sales')
plt.title('Yearly Sales Percentage')
plt.show()
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
# Car Year
# 2010    5781746875
# 2011    5751909061
# 2012    5776172347
# 2013    5785345440
# 2014    5779464242
# 2015    5787448830
# 2016    5777008549
# 2017    5785627889
# 2018    5776261553
# 2019    5768079806
# 2020    5782422975
# 2021    5744104226
# 2022    5734855062
# Name: Sale Price, dtype: int64

# %% [markdown]
# **The year 2015 having the highest sales and the year 2022 having the lowest sales.**

# %% [markdown]
# # Train The model

# %%
x = np.array(yearly_sales.index.tolist()).reshape((-1, 1))
y = np.array(yearly_sales.tolist())
print(x,y)
# Out:
# [[2010]
#  [2011]
#  [2012]
#  [2013]
#  [2014]
#  [2015]
#  [2016]
#  [2017]
#  [2018]
#  [2019]
#  [2020]
#  [2021]
#  [2022]] [5781746875 5751909061 5776172347 5785345440 5779464242 5787448830
#  5777008549 5785627889 5776261553 5768079806 5782422975 5744104226
#  5734855062]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
r_sq = model.score(x, y)
print(f"coefficient of determination: {r_sq}")
# Out:
# coefficient of determination: 0.19844958855630945

# %%
y_pred = model.predict(x)
print(f"predicted response:\n{y_pred}")
# Out:
# predicted response:
# [5.78328918e+09 5.78133645e+09 5.77938373e+09 5.77743101e+09
#  5.77547828e+09 5.77352556e+09 5.77157284e+09 5.76962011e+09
#  5.76766739e+09 5.76571466e+09 5.76376194e+09 5.76180922e+09
#  5.75985649e+09]

# %% [markdown]
# # **Correlation Matrix**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /tmp/ipykernel_34/384835012.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

# %%
print(df.corr())
# Out:
#                    Car Year  Sale Price  Commission Rate  Commission Earned
# Car Year           1.000000   -0.000667        -0.000311          -0.000713
# Sale Price        -0.000667    1.000000         0.000474           0.779319
# Commission Rate   -0.000311    0.000474         1.000000           0.585176
# Commission Earned -0.000713    0.779319         0.585176           1.000000
# /tmp/ipykernel_34/4212406737.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.corr())

# %% [markdown]
# * Based on the correlation matrix you provided, there seems to be a positive correlation between the sale price and commission earned variables, with a correlation coefficient of 0.78. This suggests that as the sale price of a car increases, the commission earned by the salesperson also tends to increase.
# * There is also a moderate positive correlation between commission rate and commission earned, with a correlation coefficient of 0.59. This indicates that higher commission rates are associated with higher commission earnings for the salesperson.
# * However, there is no correlation between car year and the other variables, as the correlation coefficients are very close to zero.

# %% [markdown]
# **Is there a relationship between the car make and the sale price?**

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Car Make'], df['Sale Price'])
plt.xlabel('Car Make')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
# **Do newer cars generally have higher sale prices?**

# %%
corr = df['Car Year'].corr(df['Sale Price'])
print(corr)
# Out:
# -0.0006665070424949136

# %% [markdown]
# The correlation between Car Year and Sale Price is -0.0006665, which indicates a very weak negative correlation. Therefore, it can be concluded that there is no significant relationship between the age of the car and its sale price in this dataset.

# %% [markdown]
# **Is there a difference in commission earned between different car models?**

# %%
model_commission = df.groupby('Car Model')['Commission Earned'].mean()
print(model_commission)

# %% [markdown]
# The values in **model_commission** show that the average commission earned for each car model is relatively similar, with values ranging from **2997.87 to 3003.31**. However, these differences are quite small and may not be significant in practice.

# %% [markdown]
# **Do certain salespersons perform better than others in terms of sales or commission earned?**

# %%
salesperson_sales = df.groupby('Salesperson')['Sale Price'].sum()
salesperson_commission = df.groupby('Salesperson')['Commission Earned'].sum()

# Sort by total sales
salesperson_sales = salesperson_sales.sort_values(ascending=False)

# Sort by commission earned
salesperson_commission = salesperson_commission.sort_values(ascending=False)

# %%
salesperson_commission
# Out:
# Salesperson
# Michael Smith         3658467.56
# Michael Johnson       2883629.29
# David Smith           2456566.33
# James Smith           2448405.59
# Robert Smith          2275950.52
#                          ...
# Christy Pennington        510.12
# Cheryl Erickson           508.91
# Mr. Joseph Garrett        508.32
# Felicia Mcneil            506.50
# James Rogers DDS          503.33
# Name: Commission Earned, Length: 518657, dtype: float64

# %%
salesperson_total_commission = df.groupby('Salesperson')['Commission Earned'].sum().sort_values(ascending=False)
print(salesperson_total_commission)
# Out:
# Salesperson
# Michael Smith         3658467.56
# Michael Johnson       2883629.29
# David Smith           2456566.33
# James Smith           2448405.59
# Robert Smith          2275950.52
#                          ...
# Christy Pennington        510.12
# Cheryl Erickson           508.91
# Mr. Joseph Garrett        508.32
# Felicia Mcneil            506.50
# James Rogers DDS          503.33
# Name: Commission Earned, Length: 518657, dtype: float64

# %% [markdown]
# After analyzing the car sales data, several insights were obtained. The dataset contained information about car sales, including the car model, car make, salesperson, sale price, commission rate, commission earned, and car year.
#
# Some of the key findings from the analysis include:
#
# * The top 5 car models sold were the **Silverado, Civic, Corolla, F-150, and Altima.**
# * The top 5 car makes sold were **Honda, Chevrolet, Toyota, Ford, and Nissan.**
# * The top 5 salespersons in terms of commission earned were **Michael Smith, Michael Johnson, David Smith, James Smith, and Robert Smith.**
# * The car model with the highest sales was the **Silverado**, followed closely by the Civic and Corolla.
# * The car make with the highest sales was **Toyota**, followed closely by Honda and Chevrolet.
# * There was a weak negative correlation between car year and sale price, suggesting that newer cars did not necessarily have higher sale prices.
# * There was no strong correlation between car make and sale price.
# * There was a slight difference in commission earned between different car models, with Corolla having the highest commission earned and F-150 having the lowest.
# * Overall, this analysis provides some useful insights into the car sales data. However, further analysis could be performed to gain a deeper understanding of the data, such as analyzing the relationship between commission rate and commission earned, or examining the performance of individual salespersons over time.
